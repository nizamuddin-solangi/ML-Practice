# %%
import pandas as pd

# %%
srs = pd.Series(["Nizamuddin", "Aiesh", "Usaid", "Hamdan"])

# %%
srs
# Out:
# 0    Nizamuddin
# 1         Aiesh
# 2         Usaid
# 3        Hamdan
# dtype: object

# %%
data = {
    "Name" : ["Nizamuddin", "Aiesh", "Usaid", "Hamdan"],
    "Teacher": "Miss Fatima",
    "Batch Code": "AI2025-05C"
}

df = pd.DataFrame(data)
print(df)
# Out:
#          Name      Teacher  Batch Code
# 0  Nizamuddin  Miss Fatima  AI2025-05C
# 1       Aiesh  Miss Fatima  AI2025-05C
# 2       Usaid  Miss Fatima  AI2025-05C
# 3      Hamdan  Miss Fatima  AI2025-05C

# %%
df[['Teacher', 'Batch Code']]
# Out:
#        Teacher  Batch Code
# 0  Miss Fatima  AI2025-05C
# 1  Miss Fatima  AI2025-05C
# 2  Miss Fatima  AI2025-05C
# 3  Miss Fatima  AI2025-05C

# %%
df[df['Name'].str.endswith('n')]
# Out:
#          Name      Teacher  Batch Code
# 0  Nizamuddin  Miss Fatima  AI2025-05C
# 3      Hamdan  Miss Fatima  AI2025-05C

# %%
df['Ends_with_N'] = df['Name'].str.endswith('n')

# %%
print(df)
# Out:
#          Name      Teacher  Batch Code  Ends_with_N
# 0  Nizamuddin  Miss Fatima  AI2025-05C         True
# 1       Aiesh  Miss Fatima  AI2025-05C        False
# 2       Usaid  Miss Fatima  AI2025-05C        False
# 3      Hamdan  Miss Fatima  AI2025-05C         True

# %%
df.isnull().sum()
# Out:
# Name           0
# Teacher        0
# Batch Code     0
# Ends_with_N    0
# dtype: int64

# %% [markdown]
# # Practice Work

# %%
std_data = [
    {
        "Name": "Nizamuddin",
        "Hours Studied": 3,
        "Sleep Hours": 10,
        "Score": 79
    },
    {
        "Name": "Aiesh",
        "Hours Studied": 2,
        "Sleep Hours": 11,
        "Score": 68
    },
    {
        "Name": "Usaid",
        "Hours Studied": 5,
        "Sleep Hours": 8,
        "Score": 83
    },
    {
        "Name": "Hamdan",
        "Hours Studied": 1,
        "Sleep Hours": 9,
        "Score": 58
    }
]

df = pd.DataFrame(std_data)
df
# Out:
#          Name  Hours Studied  Sleep Hours  Score
# 0  Nizamuddin              3           10     79
# 1       Aiesh              2           11     68
# 2       Usaid              5            8     83
# 3      Hamdan              1            9     58

# %%
df[df['Score'] > 80]
# Out:
#     Name  Hours Studied  Sleep Hours  Score
# 2  Usaid              5            8     83

# %%
df['Performance'] = df['Score'].apply(lambda x: 'High' if x > 60 else 'Low')
df
# Out:
#          Name  Hours Studied  Sleep Hours  Score Performance
# 0  Nizamuddin              3           10     79        High
# 1       Aiesh              2           11     68        High
# 2       Usaid              5            8     83        High
# 3      Hamdan              1            9     58         Low

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_json("data.json")
df
# Out:
#           Name  Hours Studied  Sleep Hours  Score
# 0   Nizamuddin              3           10     79
# 1        Aiesh              2           11     68
# 2        Usaid              5            8     83
# 3       Hamdan              1            9     58
# 4          Ali              4            7     81
# 5        Ahmed              6            6     88
# 6         Sara              5            7     85
# 7       Ayesha              2            9     65
# 8        Bilal              3            8     72
# 9         Zain              1           10     55
# 10      Hassan              4            7     78
# 11      Fatima              6            6     90
# 12        Umar              5            8     84
# 13        Noor              3            9     70
# 14        Saad              2            8     66
# 15        Hira              4            7     80
# 16        Asad              6            5     89
# 17        Iqra              3            8     74
# ...

# %%
features = df.drop('Score', axis=1)

# %%
target = df['Score']

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.3,random_state=3)

# %%
model = LinearRegression()

# %%
model.fit(features_train,target_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13560\3550617166.py in ?()
# ----> 1 model.fit(features_train,target_train)
#
# c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     626         n_jobs_ = self.n_jobs
#     627
#     628         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     629
# ...

# %%
features = features.drop("Name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 features = features.drop(columns='Name')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.3,random_state=3)

# %%
model = LinearRegression()

# %%
model.fit(features_train, target_train)
# Out:
# LinearRegression()

# %%
target_prdt = model.predict(features_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
target_test
# Out:
# 14    66
# 2     83
# 1     68
# 17    74
# 4     81
# 16    89
# Name: Score, dtype: int64

# %%
target_prdt
# Out:
# array([63.41320293, 85.29486553, 64.97848411, 70.70709046, 77.4792176 ,
#        91.02347188])

# %%
print(r2_score(target_test, target_prdt))
# Out:
# 0.8809805354881
