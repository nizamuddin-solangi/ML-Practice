# %%
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_json('fitness_data.json')
df
# Out:
#      Name  Workout_Hours  Sleep_Hours  Junk_Food_Meals Fitness_Level
# 0     Ali              5            7                2          High
# 1   Ahmed              1            6                5           Low
# 2    Sara              4            8                1          High
# 3  Ayesha              2            7                4           Low
# 4   Usaid              6            7                1          High
# 5  Hamdan              1            5                6           Low
# 6    Zain              3            6                3           Low
# 7  Hassan              5            8                2          High
# 8  Fatima              4            7                2          High
# 9    Umar              2            6                4           Low

# %%
target = df['Fitness_Level']

# %%
features = df[['Workout_Hours', 'Sleep_Hours', 'Junk_Food_Meals']]

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.2,random_state=3)

# %%
model.fit(features_train, target_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.fit(features_train, target_train)
#
# File c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:630, in LinearRegression.fit(self, X, y, sample_weight)
#     626 n_jobs_ = self.n_jobs
#     628 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
target = target.apply(lambda x:1 if x == "high" else 0)

# %%
features_train,features_test,target_train,target_test =train_test_split(features,target,test_size=0.2,random_state=3)

# %%
model = LinearRegression()

# %%
model.fit(features_train, target_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
target_test
# Out:
# 5    0
# 4    0
# Name: Fitness_Level, dtype: int64

# %%
target_prdt = model.predict(features_test)

# %%
target_prdt
# Out:
# array([0., 0.])

# %%
print(r2_score(target_test, target_prdt))
# Out:
# 1.0

# %%
pred = model.predict(features_test)
pred
# Out:
# array([0., 0.])
