# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["Ali", "Ahmed", "Sara", "Ayesha", "Usaid"],
    "Age": [18, 19, 18, 20, 19],
    "Marks": [78, 85, 90, 72, 88]
}

df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#     Name  Age  Marks
# 0    Ali   18     78
# 1  Ahmed   19     85
# 2   Sara   18     90

# %%
df.tail(2)
# Out:
#      Name  Age  Marks
# 3  Ayesha   20     72
# 4   Usaid   19     88

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
print(df['Marks'].mean())
# Out:
# 82.6

# %%
maxmarks = df['Marks'].idxmax()
std_name = df.loc[maxmarks, 'Name']
print(std_name)
# Out:
# Sara

# %%
sort = df.sort_values(by="Marks")
sort
# Out:
#      Name  Age  Marks
# 3  Ayesha   20     72
# 0     Ali   18     78
# 1   Ahmed   19     85
# 4   Usaid   19     88
# 2    Sara   18     90

# %%
df.query('Marks > 80')
# Out:
#     Name  Age  Marks
# 1  Ahmed   19     85
# 2   Sara   18     90
# 4  Usaid   19     88

# %%
df.query('Marks > 80 & Age == 19')
# Out:
#     Name  Age  Marks
# 1  Ahmed   19     85
# 4  Usaid   19     88

# %%
df['Passed'] = np.where(df['Marks'] >= 75, "True", "False")
df
# Out:
#      Name  Age  Marks Passed
# 0     Ali   18     78   True
# 1   Ahmed   19     85   True
# 2    Sara   18     90   True
# 3  Ayesha   20     72  False
# 4   Usaid   19     88   True

# %%
df['Marks'] + 5
# Out:
# 0    83
# 1    90
# 2    95
# 3    77
# 4    93
# Name: Marks, dtype: int64

# %%
passed = df['Passed'].sum()
passed
# Out:
# 'TrueTrueTrueFalseTrue'
