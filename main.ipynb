# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ALIKHAN4/SMIT_BATCH_8/refs/heads/main/Machine_Learning/Student_Performance.csv')

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
print(df.duplicated().sum())
# Out:
# 127

# %%
df.drop_duplicates(inplace=True)

# %%
features = df.drop('Performance Index', axis=1)

# %%
target = df['Performance Index']

# %%
target
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 9873, dtype: float64

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.3,random_state=3)

# %%
model = LinearRegression()

# %%
model.fit(features_train,target_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\3550617166.py in ?()
# ----> 1 model.fit(features_train,target_train)
#
# c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Nizamuddin Solangi\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     626         n_jobs_ = self.n_jobs
#     627
#     628         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     629
# ...

# %%
features['Extracurricular Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
features['Extracurricular Activities'] = features['Extracurricular Activities'].apply(lambda x: 1 if x == 'yes' else 0)

# %%
features
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           0            9
# 1                 4               82                           0            4
# 2                 8               51                           0            7
# 3                 5               52                           0            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           0            4
# 9996              7               64                           0            8
# 9997              6               83                           0            8
# 9998              9               97                           0            7
# 9999              7               74                           0            8
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.3,random_state=3)

# %%
features_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 7315              1               62                           0            5
# 2059              3               69                           0            4
# 3952              8               91                           0            5
# 7847              9               74                           0            9
# 4633              8               75                           0            4
# ...             ...              ...                         ...          ...
# 6453              4               50                           0            6
# 9271              3               68                           0            5
# 9986              1               48                           0            8
# 1691              8               91                           0            7
# 6033              1               72                           0            4
#
# ...

# %%
model = LinearRegression()

# %%
model.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
target_prdt = model.predict(features_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
target_test
# Out:
# 5624    78.0
# 194     54.0
# 2182    83.0
# 640     40.0
# 949     38.0
#         ...
# 3654    45.0
# 1571    44.0
# 4437    63.0
# 5406    31.0
# 9222    34.0
# Name: Performance Index, Length: 2962, dtype: float64

# %%
target_prdt
# Out:
# array([77.17289827, 56.28198747, 81.83177892, ..., 63.46566949,
#        30.00556636, 35.00561639], shape=(2962,))

# %%
print(r2_score(target_test, target_prdt))
# Out:
# 0.9880846993180504
